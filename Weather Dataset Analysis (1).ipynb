# %%
import pandas as pd

# %%
Weather_ds= pd.read_csv("C:\\Users\\VINIT SANDESH\\Desktop\\DATA ANALYTICS\\PYTHON\\PROJECT DATASETS\\Weather Dataset.csv")
Weather_ds
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
Weather_ds.head(10)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
# 5  01-01-2012 05:00    -1.4              -3.3         87                9
# 6  01-01-2012 06:00    -1.5              -3.1         89                7
# 7  01-01-2012 07:00    -1.4              -3.6         85                7
# 8  01-01-2012 08:00    -1.4              -3.6         85                9
# 9  01-01-2012 09:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
Weather_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
Weather_ds.shape
# Out:
# (8784, 8)

# %%
Weather_ds.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
Weather_ds.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
Weather_ds.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
Weather_ds.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
Weather_ds.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
Weather_ds["Temp_C"].value_counts()
# Out:
# Temp_C
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#          ..
# -20.7     1
# -21.0     1
#  31.8     1
#  32.6     1
# -21.3     1
# Name: count, Length: 533, dtype: int64

# %%
Weather_ds["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
Weather_ds.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
# .Unique() Values
Weather_ds["Wind Speed_km/h"].unique() # - All Unique Wind Speed Data Values
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
# value.counts()
Weather_ds.Weather.value_counts().head(10)
# Out:
# Weather
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Rain              306
# Rain Showers      188
# Fog               150
# Rain,Fog          116
# Drizzle,Fog        80
# Name: count, dtype: int64

# %%
Weather_ds[Weather_ds.Weather ==  'Clear'].head(5) # - Find the no. of times when the "Weather is Exactly clear.
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   01-03-2012 19:00   -16.9             -24.8         50               24
# 114  01-05-2012 18:00    -7.1             -14.4         56               11
# 115  01-05-2012 19:00    -9.2             -15.4         61                7
# 116  01-05-2012 20:00    -9.8             -15.7         62                9
# 117  01-05-2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
#Using Groupby Method
Weather_ds.groupby('Weather').get_group('Clear').tail(6)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8645   12/26/2012 5:00   -12.7             -14.1         89                4
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# 8645           25.0     102.48   Clear
# 8646           25.0     102.47   Clear
# 8698           24.1     101.27   Clear
# 8713           25.0     101.31   Clear
# 8714           25.0     101.33   Clear
# 8756           25.0     101.52   Clear

# %%
Weather_ds[Weather_ds['Wind Speed_km/h']== 4] # - No. of Times when the "wind speed was exactly 4 Km/hr"
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 96    01-05-2012 00:00    -8.8             -11.7         79                4
# 101   01-05-2012 05:00    -7.0              -9.5         82                4
# 146   01-07-2012 02:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
Weather_ds.isnull().sum() # - All the Null values in the data
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
Weather_ds.rename(columns = {'Weather' : 'Weather_Condition'}, inplace = True ) # - Renamed the column name ( Weather = Weather Condition)
Weather_ds.head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# Weather_ds.Visibility_km.mean() - Mean Of visibility_km
print('Visibility_km mean Output: ',Weather_ds.Visibility_km.mean())
# Out:
# Visibility_km mean Output:  27.664446721311478

# %%
import pandas as pd
import matplotlib.pyplot as plt

mean_visibility = Weather_ds.Visibility_km.mean()

# Print mean visibility
print('Visibility_km mean Output:', mean_visibility)

plt.bar(['Mean Visibility'], [mean_visibility])
plt.title('Mean Visibility')
plt.ylabel('Visibility (km)')
plt.show()
# Out:
# Visibility_km mean Output: 27.664446721311478

# %%
# Standard deviation of Pressure (A standard deviation (or σ) is a measure of how dispersed the data is in relation to the mean.)
print('Standard deviation of Pressure: ',Weather_ds.Press_kPa.std())
# Out:
# Standard deviation of Pressure:  0.8440047459486474

# %%
                                        #All instance when Snow Was Recorded
Weather_ds.head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
variance = Weather_ds['Rel Hum_%'].var()        # Variance of Relative Humidity
print('variance of Relative Humidity: ', variance)
# Out:
# variance of Relative Humidity:  286.2485501984998

# %%
Weather_ds[Weather_ds['Weather_Condition']== 'Snow']      # Only Individual Snow Object Identification
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01-03-2012 07:00   -14.0             -19.5         63               19
# 84    01-04-2012 12:00   -13.7             -21.7         51               11
# 86    01-04-2012 14:00   -11.3             -19.0         53                7
# 87    01-04-2012 15:00   -10.2             -16.3         61               11
# 88    01-04-2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
Weather_ds[Weather_ds['Weather_Condition'].str.contains('Snow')].head(20) # For Multiple Snow Object with Diff. Object Identification
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41  01-02-2012 17:00    -2.1              -9.5         57               22
# 44  01-02-2012 20:00    -5.6             -13.4         54               24
# 45  01-02-2012 21:00    -5.8             -12.8         58               26
# 47  01-02-2012 23:00    -7.4             -14.1         59               17
# 48  01-03-2012 00:00    -9.0             -16.0         57               28
# 50  01-03-2012 02:00   -10.5             -15.8         65               22
# 51  01-03-2012 03:00   -11.3             -18.7         54               33
# 53  01-03-2012 05:00   -12.9             -19.1         60               22
# 54  01-03-2012 06:00   -13.3             -19.3         61               19
# 55  01-03-2012 07:00   -14.0             -19.5         63               19
# 84  01-04-2012 12:00   -13.7             -21.7         51               11
# ...

# %%
Weather_ds[(Weather_ds['Wind Speed_km/h'] > 20) & (Weather_ds['Visibility_km'] == 25)].head(5)  #Finding Wind Speed Above 24 & Visibility is 25
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  01-01-2012 23:00     5.3               2.0         79               30
# 24  01-02-2012 00:00     5.2               1.5         77               35
# 25  01-02-2012 01:00     4.6               0.0         72               39
# 26  01-02-2012 02:00     3.9              -0.9         71               32
# 27  01-02-2012 03:00     3.7              -1.5         69               33
#
#     Visibility_km  Press_kPa Weather_Condition
# 23           25.0      99.31            Cloudy
# 24           25.0      99.26      Rain Showers
# 25           25.0      99.26            Cloudy
# 26           25.0      99.26     Mostly Cloudy
# 27           25.0      99.30     Mostly Cloudy

# %%
Weather_ds.groupby('Weather_Condition').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                    01-03-2012 19:00   -23.3
# Cloudy                                   01-01-2012 17:00   -21.4
# Drizzle                                  05-01-2012 15:00     1.1
# Drizzle,Fog                              05-01-2012 16:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                      01-01-2012 00:00   -16.0
# Freezing Drizzle                         01-07-2012 11:00    -9.0
# Freezing Drizzle,Fog                     01-01-2012 02:00    -6.4
# Freezing Drizzle,Haze                    02-01-2012 11:00    -5.8
# Freezing Drizzle,Snow                    03-02-2012 12:00    -8.3
# Freezing Fog                             02-05-2012 10:00   -19.0
# ...

# %%
Weather_ds.groupby('Weather_Condition').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather_Condition
# Clear                                      9/28/2012 4:00    32.8
# Cloudy                                     9/30/2012 9:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                          12/17/2012 0:00    -2.3
# Freezing Drizzle,Fog                     12-10-2012 05:00    -0.3
# Freezing Drizzle,Haze                    02-01-2012 13:00    -5.0
# Freezing Drizzle,Snow                     12/28/2012 2:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
Weather_ds[Weather_ds['Weather_Condition'].str.contains('Fog')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90               11
# 8740   12/30/2012 4:00    -9.3             -10.6         90               13
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %%
Weather_ds[(Weather_ds['Weather_Condition'] == "Clear") | (Weather_ds['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 106   01-05-2012 10:00    -6.0             -10.0         73               17
# 107   01-05-2012 11:00    -5.6             -10.2         70               22
# 108   01-05-2012 12:00    -4.7              -9.6         69               20
# 109   01-05-2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
Weather_ds[(Weather_ds['Weather_Condition'] == "Clear") & (Weather_ds['Rel Hum_%'] > 50) | (Weather_ds['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106   01-05-2012 10:00    -6.0             -10.0         73               17
# 107   01-05-2012 11:00    -5.6             -10.2         70               22
# 108   01-05-2012 12:00    -4.7              -9.6         69               20
# 109   01-05-2012 13:00    -4.4              -9.7         66               26
# 110   01-05-2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
Weather_ds.to_excel("C:\\Users\\VINIT SANDESH\\Desktop\\DATA ANALYTICS\\PYTHON\\PROJECT DATASETS\\Weather_data_pandas.xlsx", index=False)
